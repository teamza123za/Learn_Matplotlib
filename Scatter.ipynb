# %%
import matplotlib.pyplot as plt

# %%
size = [100,200,300,100,300]
color = ["red","orange","green","purple","yellow"]
x = [1,2,3,4,5]
y = [1.2,2.3,3.4,4.5,4.3]

# %%
plt.scatter(x,y,s=size,c=color)
plt.show()
