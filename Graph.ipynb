# %%
import matplotlib.pyplot as plt

# %%
x= [10,20,30,40,50]
y = [10,20,30,40,50]

# %%
plt.bar(y,x)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.show()

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
product1 = [10,20,30,40,50]
product2 = [11,220,330,450,540]
month = [1,2,3,4,5]

# %%
plt.plot(month,product1)
plt.plot(month,product2)

# %%
plt.show()

# %%
plt.bar(month,product2)
# Out:
# <BarContainer object of 5 artists>
